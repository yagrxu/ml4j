# %%
import pandas as pd

sample = pd.read_csv(r'C:\Users\jduan\Documents\Bayer\datacleansing.csv')

sample['MaterialSending'] = sample['MaterialSending'].astype(str)
sample = sample.groupby('VendorName').agg(lambda x: ';'.join(set(x))).reset_index()

sample.head()
# Out:
#                                   VendorName  \
# 0             ADP CONSEIL SARL, CHEVREUSE_FR
# 1       Aloysius Krenzer KG, Poppenhausen_DE
# 2    Artur Theis GmbH & Co. KG, Wuppertal_DE
# 3             Artur Theis GmbH, Wuppertal_DE
# 4  August Faller GmbH & Co. KG, Waldkirch_DE
#
#                                      MaterialSending  \
# 0                                           81671052
# 1                                           19100033
# 2  81815712;81066280;81474850;81531285;81142645;8...
# 3  81815712;83637472;81488150;84013110;84827460;8...
# 4  81221316;80601492;80601514;81794219;84135313;8...
#
#                                  MaterialNameSending  \
# 0                           Pochette transport Eylea
# 1                                        Europalette
# 2  FB-2DMC-Eylea 2MG VL 1x2ML ACF;FB-Eylia 2MG VL...
# 3  FB-Eylea 2MG VL 1x2ML;FB-2DMC-Eylea 2MG VL 1x2...
# 4  FB-Eylia 2MG VL 1x2ML ACF;LF-OUTS-Eylea 2MG VL...
#
# ...

# %%
# Out:
#                                 VendorName  MaterialSending  \
# 0           ADP CONSEIL SARL, CHEVREUSE_FR         81671052
# 1     Aloysius Krenzer KG, Poppenhausen_DE         19100033
# 2  Artur Theis GmbH & Co. KG, Wuppertal_DE         80467907
# 3  Artur Theis GmbH & Co. KG, Wuppertal_DE         80467915
# 4  Artur Theis GmbH & Co. KG, Wuppertal_DE         80789947
#
#          MaterialNameSending          FinalMaterial            Category  \
# 0   Pochette transport Eylea          Eylea, Parent  Packaging material
# 1                Europalette  Eylea 2Mg/0,05 Ml Sol  Packaging material
# 2     FS-Eylea 2MG FSP 1x1ML  Eylea 2Mg/0,05 Ml Sol  Packaging material
# 3     FS-Eylea 2MG FSP 1x1ML  Eylea 2Mg/0,05 Ml Sol  Packaging material
# 4  FB-Eylea 2MG VL 1x2ML ACF  Eylea 2Mg/0,05 Ml Sol  Packaging material
#
#             FinalProduct
# 0          Eylea, Parent
# 1  Eylea 2Mg/0,05 Ml Sol
# 2  Eylea 2Mg/0,05 Ml Sol
# 3  Eylea 2Mg/0,05 Ml Sol
# 4  Eylea 2Mg/0,05 Ml Sol
